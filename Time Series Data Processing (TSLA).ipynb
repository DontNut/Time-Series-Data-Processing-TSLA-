# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv(r'/tmp/TSLA.csv')
df.head(10)
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 5  2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500
# 6  2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000
# 7  2010-07-09  3.516  3.580  3.310  3.480      3.480  20253000
# 8  2010-07-12  3.590  3.614  3.400  3.410      3.410  11012500
# 9  2010-07-13  3.478  3.728  3.380  3.628      3.628  13400500

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')

# %%
df.loc[2966,'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Day_Of_The_Week'] = df['Date'].dt.day_name()

# %%
df.head(10)
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume Day_Of_The_Week
# 0 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500         Tuesday
# 1 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500       Wednesday
# 2 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000        Thursday
# 3 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000          Friday
# 4 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500         Tuesday
# 5 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500       Wednesday
# 6 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000        Thursday
# 7 2010-07-09  3.516  3.580  3.310  3.480      3.480  20253000          Friday
# 8 2010-07-12  3.590  3.614  3.400  3.410      3.410  11012500          Monday
# 9 2010-07-13  3.478  3.728  3.380  3.628      3.628  13400500         Tuesday

# %%
df.set_index('Date' , inplace=True)

# %%
df.head(10)
# Out:
#              Open   High    Low  Close  Adj Close    Volume Day_Of_The_Week
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500         Tuesday
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500       Wednesday
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000        Thursday
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000          Friday
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500         Tuesday
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500       Wednesday
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000        Thursday
# 2010-07-09  3.516  3.580  3.310  3.480      3.480  20253000          Friday
# 2010-07-12  3.590  3.614  3.400  3.410      3.410  11012500          Monday
# 2010-07-13  3.478  3.728  3.380  3.628      3.628  13400500         Tuesday

# %%
print('Max Close Price in 2021-01-01 to 2022-04-08:','$',df['2021-01':]['Close'].max())
print('Min Close Price in 2021-01-01 to 2022-04-08:','$',df['2021-01':]['Close'].min())
print('Mean Close Price in 2021-01-01 to 2022-04-08:','$',df['2021-01':]['Close'].mean())
df['2021-01':]['Close'].plot()
# Out:
# Max Close Price in 2021-01-01 to 2022-04-08: $ 1229.910034
# Min Close Price in 2021-01-01 to 2022-04-08: $ 563.0
# Mean Close Price in 2021-01-01 to 2022-04-08: $ 815.4416534281246
# <AxesSubplot:xlabel='Date'>
